# %%
import os, sys, glob, joblib, copy
sys.path.append(r'/Users/khcho/Desktop/IRIS-moss-main/iris2plus_new/iris_lmsalpy')

# %%
# %matplotlib qt5
# %matplotlib inline

# from iris_lmsalpy import showIRIS
from iris_lmsalpy import data2model_knnmultiline_inn
import matplotlib.pyplot as plt
import numpy as np
import os
from importlib import reload
# Out:
# WARNING: SunpyUserWarning: Importing sunpy.map without its extra dependencies may result in errors.
# The following packages are not installed:
# ['mpl-animators>=1.0.0', 'reproject>=0.9.0']
# To install sunpy with these dependencies use `pip install sunpy[map]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org [sunpy.util.sysinfo]
# WARNING: SunpyUserWarning: Importing sunpy.visualization without its extra dependencies may result in errors.
# The following packages are not installed:
# ['mpl-animators>=1.0.0']
# To install sunpy with these dependencies use `pip install sunpy[visualization]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org [sunpy.util.sysinfo]
#
# A module that was compiled using NumPy 1.x cannot be run in
# ...

# %%
from scipy.io import readsav
path = '/Users/khcho/Desktop/IRIS-moss-main/iris2plus_new/'
os.chdir(path)
idl_save_file = readsav('/Users/khcho/Desktop/IRIS-moss-main/moss_param_event_total_mg2.sav')

for key in idl_save_file.keys():
    exec(key+' = idl_save_file["'+key+'"]')

# %%
pars_pix_peak_ind = idl_save_file['pars_pix_peak_ind']
sg_files = idl_save_file['sg_file'][pars_pix_peak_ind]
sg_files = [sg_file.decode('ASCII') for sg_file in sg_files]
sg_ind = np.array(idl_save_file['sg_ind'])[pars_pix_peak_ind]
uniq_sg_files = np.array(sorted(list(set(sg_files))))

# %%
# from old IRIS2p inversion, get weight for line based spatialy averaged intensity. 
# give 0 weight for photospheric lines manually. 

chro_lines = [1334.55, 1335.72, 2791.6, 2796.35, 2798.8, 2803.53]
old_file_path = '/Users/khcho/Desktop/IRIS-moss-main/iris2plus/chro_photo/'
old_iris2p_files = sorted(glob.glob(old_file_path+'inv_mod_IRIS2p_201*.jbl'))

if True:
    for sg_file0 in uniq_sg_files:
        print(f"Processing file: {sg_file0}")
        obsid = sg_file0.split('/')[-2]
        old_file = [i for i in old_iris2p_files if obsid in i][0]
        data0 = joblib.load(old_file, mmap_mode='r')
        weight = copy.deepcopy(data0['crop_wei4knn'])
        for i in range(len(weight)):
            weight[i][3] = 0
        for line in chro_lines:
            for i in range(len(weight)):
                if abs(line - weight[i][2]) < 0.1:
                    weight[i][3] = data0['crop_wei4knn'][i][3]
                    continue
        print(weight)            
        out = data2model_knnmultiline_inn.invert(
                sg_file0, 
                database='ar4iris2', 
                radloss=True, 
                output_dir = path+'chromosphere/',
                crop_wei4knn= weight, 
            )
        del(data0, out)
# Out:
# Processing file: /irisa/data/level2/2015/09/16/20150916_044717_3680086902/iris_l2_20150916_044717_3680086902_raster_t000_r00000.fits
# [[np.int64(50), np.int64(112), 1334.55, np.float64(86.74017426115753)], [np.int64(140), np.int64(202), 1335.72, np.float64(68.63203988539937)], [np.int64(246), np.int64(253), 2785.46, 0], [np.int64(288), np.int64(303), 2791.6, np.float64(3.265433334771588)], [np.int64(328), np.int64(336), 2793.22, 0], [np.int64(397), np.int64(475), 2796.35, np.float64(1.0)], [np.int64(525), np.int64(540), 2798.8, np.float64(4.629443053580324)], [np.int64(679), np.int64(757), 2803.53, np.float64(1.2193402635636792)], [np.int64(823), np.int64(835), 2809.15, 0], [np.int64(869), np.int64(901), 2810.58, 0], [np.int64(913), np.int64(921), 2815.18, 0], [np.int64(935), np.int64(943), 2827.33, 0]]
# Loading... /Users/khcho/Desktop/IRIS-moss-main/iris2plus_new/iris_lmsalpy/iris_lmsalpy/data/NIST_2783_2835_onlyobs.jbl.gz
# Reference time is 20150916_04471942 (index 0)
# ...

# %%
# from old IRIS2p inversion, get weight for line based spatialy averaged intensity. 
# give 0 weight for photospheric lines manually. 

chro_lines = [1334.55, 1335.72, 2791.6, 2796.35, 2798.8, 2803.53]
old_file_path = '/Users/khcho/Desktop/IRIS-moss-main/iris2plus/chro_photo/'
old_iris2p_files = sorted(glob.glob(old_file_path+'inv_mod_IRIS2p_201*.jbl'))

if True:
    for sg_file0 in uniq_sg_files[:1]:
        print(f"Processing file: {sg_file0}")
        obsid = sg_file0.split('/')[-2]
        for old_file in old_iris2p_files:
            if obsid in old_file:
                data0 = joblib.load(old_file, mmap_mode='r')
                break
        weight = copy.deepcopy(data0['crop_wei4knn'])
# Out:
# Processing file: /irisa/data/level2/2015/09/16/20150916_044717_3680086902/iris_l2_20150916_044717_3680086902_raster_t000_r00000.fits

# %%
aa = [i for i in old_iris2p_files if obsid in i]
aa
# Out:
# ['/Users/khcho/Desktop/IRIS-moss-main/iris2plus/chro_photo/inv_mod_IRIS2p_20150916_044717_3680086902.jbl']

# %%
old_file
# Out:
# '/Users/khcho/Desktop/IRIS-moss-main/iris2plus/chro_photo/inv_mod_IRIS2p_20150916_044717_3680086902.jbl'

# %%
for old_iris2p_file in old_iris2p_files:
    data0 = joblib.load(old_iris2p_file, mmap_mode='r')
    print(data0['crop_wei4knn'][0][3])
# Out:
# 86.74017426115753
# 94.13648527904905
# 144.10149082615422
# 193.3599150508183
# 171.64009276859872
# 191.32591507908165
# 124.10353029055395
# 109.97457217204257
# 73.52095162183187
# 98.3773262945053
# 89.07987095236159
# 87.2276775056315
# 106.29382240742078
# 186.87023195790744
# 215.3349092177112
# 163.6011899019859
# 158.92887159438737
# 157.99386297359143
# 158.29128842609364
# 137.63576620927662
# 139.78616547117133
# 126.59243319017497
# 115.14760667413526
# 167.47440604446055
# 115.33083400549704
# 267.33658936027126
# 189.17128291950675
# 183.9507435573926
# 200.17446241718
# 164.2311602532461
# 191.48898193028725
# 273.3070340682506
# 225.42808057282986
# 130.45390252109092
# 225.39717665683696
# 260.48520737534045
# 261.7168730183917
# 255.87949325460238
# 246.80606102775678
# 358.78177303864106
# 399.4861080194172
# 331.86226569798663
# 334.5630099370115
# 314.5347323188499
# 340.61910497052725
# 242.1691611047874
# 222.5482255063173
# 197.94220729863747
# ...

# %%
jbl_files = glob.glob('/Users/khcho/Desktop/IRIS-moss-main/iris2plus_new/chromosphere/inv_mod_*.jbl')
for old_iris2p_file in jbl_files:
    data0 = joblib.load(old_iris2p_file, mmap_mode='r')
    print(data0['crop_wei4knn'][0][3])
# Out:
# 158.29128842609364
# 167.47440604446055
# 171.64009276859872
# 287.64518957372843
# 139.78616547117133
# 158.92887159438737
# 73.52095162183187
# 163.6011899019859
# 233.5344572734937
# 340.61910497052725
# 331.86226569798663
# 222.5482255063173
# 193.3599150508183
# 242.1691611047874
# 260.48520737534045
# 126.59243319017497
# 164.2311602532461
# 115.33083400549704
# 223.18869752467754
# 124.10353029055395
# 189.17128291950675
# 255.87949325460238
# 263.03624767827483
# 94.13648527904905
# 334.5630099370115
# 225.42808057282986
# 200.17446241718
# 137.63576620927662
# 182.87748787032635
# 260.3431358661911
# 215.3349092177112
# 314.5347323188499
# 87.2276775056315
# 246.80606102775678
# 261.7168730183917
# 218.432860493518
# 157.99386297359143
# 192.0768704862599
# 186.87023195790744
# 358.78177303864106
# 197.94220729863747
# 295.43160356154607
# 225.39717665683696
# 98.3773262945053
# 115.14760667413526
# 89.07987095236159
# 273.3070340682506
# 86.74017426115753
# ...

# %%
import os
os.getpid()
# Out:
# 6148

# %%
'''
[[ 50, 112, 1334.55, 100.0],
 [140, 202, 1335.72, 100.0],
 [246, 253, 2785.46, 2.0],
 [288, 303, 2791.60, 3.0],
 [328, 336, 2793.22, 3.0],
 [397, 475, 2796.35, 1.0],
 [525, 540, 2798.80, 3.0],
 [679, 757, 2803.53, 1.0],
 [823, 835, 2809.15, 2.0],
 [869, 901, 2810.58, 1.5],
 [913, 921, 2815.18, 1.0],
 [935, 943, 2827.33, 1.0]]


3620108103 : 2, 3, 4, 8, 9, 11
3620108404 : 2, 3, 4, 8, 9, 11
3620258403 : 2, 3, 4, 8, 9, 11
3620258404 : 2, 3, 4, 8, 9, 11
[[np.int64(50), np.int64(112), 1334.55, 100.0],
  [np.int64(140), np.int64(202), 1335.72, 100.0],
  [np.int64(244), np.int64(252), 2793.22, 3.0],  <------- 0.0
  [np.int64(313), np.int64(391), 2796.35, 1.0],
  [np.int64(441), np.int64(456), 2798.8, 3.0],
  [np.int64(595), np.int64(673), 2803.53, 1.0],
  [np.int64(743), np.int64(751), 2815.18, 1.0]])




3660109503 : 2, 8, 9 
3660259503 : 2, 8, 9
3663101603 : 2, 8, 9
3664251603 : 2, 8, 9
 [[np.int64(50), np.int64(112), 1334.55, 100.0],
  [np.int64(140), np.int64(202), 1335.72, 100.0],
  [np.int64(249), np.int64(264), 2791.6, 3.0],
  [np.int64(289), np.int64(297), 2793.22, 3.0],
  [np.int64(358), np.int64(436), 2796.35, 1.0],
  [np.int64(486), np.int64(501), 2798.8, 3.0],
  [np.int64(640), np.int64(718), 2803.53, 1.0],
  [np.int64(788), np.int64(796), 2815.18, 1.0],
  [np.int64(810), np.int64(818), 2827.33, 1.0]])

obs_368 = [[ 50, 112, 1334.55, 100.0],
         [140, 202, 1335.72, 100.0],
         [246, 253, 2785.46, 2.0],
         [288, 303, 2791.60, 3.0],
         [328, 336, 2793.22, 3.0],
         [397, 475, 2796.35, 1.0],
         [525, 540, 2798.80, 3.0],
         [679, 757, 2803.53, 1.0],
         [823, 835, 2809.15, 2.0],
         [869, 901, 2810.58, 1.5],
         [913, 921, 2815.18, 1.0],
         [935, 943, 2827.33, 1.0]]
obs_362 = [[50, 112, 1334.55, 100.0],
          [140, 202, 1335.72, 100.0],
          [244, 252, 2793.22, 0.0],  # <------- from 3.0 to 0.0
          [313, 391, 2796.35, 1.0],
          [441, 456, 2798.8, 3.0],
          [595, 673, 2803.53, 1.0],
          [743, 751, 2815.18, 1.0]]
obs_366 = [[50, 112, 1334.55, 100.0],
          [140, 202, 1335.72, 100.0],
          [249, 264, 2791.6, 3.0],
          [289, 297, 2793.22, 3.0],
          [358, 436, 2796.35, 1.0],
          [486, 501, 2798.8, 3.0],
          [640, 718, 2803.53, 1.0],
          [788, 796, 2815.18, 1.0],
          [810, 818, 2827.33, 1.0]]
'''
# Out:
# '\n[[ 50, 112, 1334.55, 100.0],\n [140, 202, 1335.72, 100.0],\n [246, 253, 2785.46, 2.0],\n [288, 303, 2791.60, 3.0],\n [328, 336, 2793.22, 3.0],\n [397, 475, 2796.35, 1.0],\n [525, 540, 2798.80, 3.0],\n [679, 757, 2803.53, 1.0],\n [823, 835, 2809.15, 2.0],\n [869, 901, 2810.58, 1.5],\n [913, 921, 2815.18, 1.0],\n [935, 943, 2827.33, 1.0]]\n\n\n3620108103 : 2, 3, 4, 8, 9, 11\n3620108404 : 2, 3, 4, 8, 9, 11\n3620258403 : 2, 3, 4, 8, 9, 11\n3620258404 : 2, 3, 4, 8, 9, 11\n[[np.int64(50), np.int64(112), 1334.55, 100.0],\n  [np.int64(140), np.int64(202), 1335.72, 100.0],\n  [np.int64(244), np.int64(252), 2793.22, 3.0],  <------- 0.0\n  [np.int64(313), np.int64(391), 2796.35, 1.0],\n  [np.int64(441), np.int64(456), 2798.8, 3.0],\n  [np.int64(595), np.int64(673), 2803.53, 1.0],\n  [np.int64(743), np.int64(751), 2815.18, 1.0]])\n\n\n\n\n3660109503 : 2, 8, 9 \n3660259503 : 2, 8, 9\n3663101603 : 2, 8, 9\n3664251603 : 2, 8, 9\n [[np.int64(50), np.int64(112), 1334.55, 100.0],\n  [np.int64(140),
# ...

# %%
# this is automatically give the weight for different lines, but no way to give 0 weight for the photospheric lines. 
if True:
    for sg_file0 in uniq_sg_files[1:]:
        print(f"Processing file: {sg_file0}")
        out = data2model_knnmultiline_inn.invert(
                sg_file0, 
                database='ar4iris2', 
                radloss=True, 
                output_dir = path+'chromosphere/',
            )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # this is automatically give the weight for different lines, but no way to give 0 weight for the photospheric lines.
#       2 if True:
# ----> 3     for sg_file0 in uniq_sg_files[1:]:
#       4         print(f"Processing file: {sg_file0}")
#       5         out = data2model_knnmultiline_inn.invert(
#       6                 sg_file0,
#       7                 database='ar4iris2',
#       8                 radloss=True,
#       9                 output_dir = path+'chromosphere/',
#      10             )
#
# NameError: name 'uniq_sg_files' is not defined

# %%
obs_368 = [[ 50, 112, 1334.55, 100.0],
         [140, 202, 1335.72, 100.0],
         [246, 253, 2785.46, 0.0],
         [288, 303, 2791.60, 3.0],
         [328, 336, 2793.22, 0.0],
         [397, 475, 2796.35, 1.0],
         [525, 540, 2798.80, 3.0],
         [679, 757, 2803.53, 1.0],
         [823, 835, 2809.15, 0.0],
         [869, 901, 2810.58, 0.0],
         [913, 921, 2815.18, 0.0],
         [935, 943, 2827.33, 0.0]]
obs_362 = [[50, 112, 1334.55, 100.0],
          [140, 202, 1335.72, 100.0],
          [244, 252, 2793.22, 0.0],  # <------- from 3.0 to 0.0
          [313, 391, 2796.35, 1.0],
          [441, 456, 2798.8, 3.0],
          [595, 673, 2803.53, 1.0],
          [743, 751, 2815.18, 0.0]]
obs_366 = [[50, 112, 1334.55, 100.0],
          [140, 202, 1335.72, 100.0],
          [249, 264, 2791.6, 3.0],
          [289, 297, 2793.22, 0.0],
          [358, 436, 2796.35, 1.0],
          [486, 501, 2798.8, 3.0],
          [640, 718, 2803.53, 1.0],
          [788, 796, 2815.18, 0.0],
          [810, 818, 2827.33, 0.0]]

if True:
    for sg_file0 in uniq_sg_files[:1]:
        if '_368' in sg_file0: weight = obs_368
        if '_366' in sg_file0: weight = obs_366
        if '_362' in sg_file0: weight = obs_362
        print(f"Processing file: {sg_file0}")
        out = data2model_knnmultiline_inn.invert(
                sg_file0, 
                database='ar4iris2', 
                radloss=True, 
                output_dir = path+'chro_photo/',
                # crop_wei4knn= weight, 
                # save_jbl_gz=True,
            )
# Out:
# Processing file: /irisa/data/level2/2015/09/16/20150916_044717_3680086902/iris_l2_20150916_044717_3680086902_raster_t000_r00000.fits
# Loading... /Users/khcho/Desktop/IRIS-moss-main/iris2plus/iris_lmsalpy/iris_lmsalpy/data/NIST_2783_2835_onlyobs.jbl.gz
# Reference time is 20150916_04471942 (index 0)
# Reference time is 20150916_04471942 (index 0)
# Calibrating data...
# Trying to load...  /Users/khcho/Desktop/IRIS-moss-main/iris2plus/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20191101.geny
# /Users/khcho/miniforge3/envs/iris2plus/lib/python3.12/site-packages/astropy/units/quantity.py:671: RuntimeWarning: divide by zero encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# Trying to load...  /Users/khcho/Desktop/IRIS-moss-main/iris2plus/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20161022.geny
# 0 - C II 1336 - 1331.68328015 to 1358.1365203862042
# 1 - Si IV 1394 - 1380.66394787 to 1406.472827867565
# ...

# %%
from iris_lmsalpy import saveall as sv
aux = sv.load('./inv_mod_IRIS2p_20150916_044717_3680086902.jbl')
# Out:
# Loading joblib file... ./inv_mod_IRIS2p_20150916_044717_3680086902.jbl
# The varible types are:
# data : <class 'numpy.memmap'>
# inv : <class 'numpy.memmap'>
# model : <class 'list'>
# wl : <class 'numpy.memmap'>
# wlc : <class 'list'>
# wl2size : <class 'list'>
# wl2scl : <class 'list'>
# extent : <class 'list'>
# extent_coords : <class 'tuple'>
# mu : <class 'numpy.float64'>
# texp : <class 'float'>
# obsid : <class 'str'>
# percentages : <class 'dict'>
# crop_wei4knn : <class 'list'>
# chi2 : <class 'numpy.memmap'>
# name_jbl : <class 'str'>
# jbl_file_saving_stamptime : <class 'str'>
#
#
# Suggested commands:
# data = aux['data']
# inv = aux['inv']
# model = aux['model']
# wl = aux['wl']
# wlc = aux['wlc']
# wl2size = aux['wl2size']
# wl2scl = aux['wl2scl']
# extent = aux['extent']
# extent_coords = aux['extent_coords']
# mu = aux['mu']
# texp = aux['texp']
# obsid = aux['obsid']
# percentages = aux['percentages']
# crop_wei4knn = aux['crop_wei4knn']
# chi2 = aux['chi2']
# ...

# %%
data = aux['data']
inv = aux['inv']
model = aux['model']
wl = aux['wl']
wlc = aux['wlc']
wl2size = aux['wl2size']
wl2scl = aux['wl2scl']
extent = aux['extent']
extent_coords = aux['extent_coords']
mu = aux['mu']
texp = aux['texp']
obsid = aux['obsid']
percentages = aux['percentages']
crop_wei4knn = aux['crop_wei4knn']
chi2 = aux['chi2']
name_jbl = aux['name_jbl']
jbl_file_saving_stamptime = aux['jbl_file_saving_stamptime']
del aux

# %%
from iris_lmsalpy import showIRIS

# %%
dci = showIRIS.iris2(data, inv, model, chi2, wl, wlc, figsize=[10,8])
# Out:
# [['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], 'T [kK]', '$v_{LOS}~[km/s]$', '$v_{turb}~[km/s]$', '$
# ...

# %%
obs_368 = [[ 50, 112, 1334.55, 100.0],
         [140, 202, 1335.72, 100.0],
         [246, 253, 2785.46, 2.0],
         [288, 303, 2791.60, 3.0],
         [328, 336, 2793.22, 3.0],
         [397, 475, 2796.35, 1.0],
         [525, 540, 2798.80, 3.0],
         [679, 757, 2803.53, 1.0],
         [823, 835, 2809.15, 2.0],
         [869, 901, 2810.58, 1.5],
         [913, 921, 2815.18, 1.0],
         [935, 943, 2827.33, 1.0]]
obs_362 = [[50, 112, 1334.55, 100.0],
          [140, 202, 1335.72, 100.0],
          [244, 252, 2793.22, 0.0],  # <------- from 3.0 to 0.0
          [313, 391, 2796.35, 1.0],
          [441, 456, 2798.8, 3.0],
          [595, 673, 2803.53, 1.0],
          [743, 751, 2815.18, 1.0]]
obs_366 = [[50, 112, 1334.55, 100.0],
          [140, 202, 1335.72, 100.0],
          [249, 264, 2791.6, 3.0],
          [289, 297, 2793.22, 3.0],
          [358, 436, 2796.35, 1.0],
          [486, 501, 2798.8, 3.0],
          [640, 718, 2803.53, 1.0],
          [788, 796, 2815.18, 1.0],
          [810, 818, 2827.33, 1.0]]


if True:
    for sg_file0 in uniq_sg_files:
        if '_368' in sg_file0: weight = obs_368
        if '_366' in sg_file0: weight = obs_366
        if '_362' in sg_file0: weight = obs_362
        print(f"Processing file: {sg_file0}")
        out = data2model_knnmultiline_inn.invert(
                sg_file0, 
                database='ar4iris2', 
                radloss=True, 
                output_dir = path+'chro_photo/',
                crop_wei4knn= weight, 
                save_jbl_gz=True,
            )
# Out:
# Processing file: /irisa/data/level2/2015/09/16/20150916_044717_3680086902/iris_l2_20150916_044717_3680086902_raster_t000_r00000.fits
# Loading... /Users/khcho/Desktop/IRIS-moss-main/iris2plus/iris_lmsalpy/iris_lmsalpy/data/NIST_2783_2835_onlyobs.jbl.gz
# Reference time is 20150916_04471942 (index 0)
# Reference time is 20150916_04471942 (index 0)
# Calibrating data...
# Trying to load...  /Users/khcho/Desktop/IRIS-moss-main/iris2plus/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20191101.geny
# /Users/khcho/miniforge3/envs/iris2plus/lib/python3.12/site-packages/astropy/units/quantity.py:671: RuntimeWarning: divide by zero encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# Trying to load...  /Users/khcho/Desktop/IRIS-moss-main/iris2plus/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20161022.geny
# 0 - C II 1336 - 1331.68328015 to 1358.1365203862042
# 1 - Si IV 1394 - 1380.66394787 to 1406.472827867565
# ...

# %%
# !pwd
# Out:
# /Users/khcho/Desktop/IRIS-moss-main/iris2plus

# %%
# If we use compressed jbl.gz file for loading using joblib, 
# the data will stay in memory because we cannot use the keyword. 
# See https://joblib.readthedocs.io/en/latest/generated/joblib.load.html#examples-using-joblib-load
import glob
import os

f = glob.glob('chro_photo/*.jbl.gz')
len(f)
for i in f:
    os.system(f'gzip -dk {i}')
